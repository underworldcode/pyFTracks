# %%
from pyAFT.thermal_history import ThermalHistoryViewer
import numpy as np

# %%
time = np.array([0., 20., 50., 100.])
temperature = np.array([20., 100., 50., 45.])

# %%
time
# Out:
# array([  0.,  20.,  50., 100.])

# %%
# %matplotlib notebook
A = ThermalHistoryViewer(time, temperature)
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
A.input_temperature
# Out:
# array([ 20., 100.,  50.,  45.])

# %%
A.original_temperature
# Out:
# array([ 20., 100.,  50.,  45.])
