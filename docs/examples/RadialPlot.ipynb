# %%
from FT.radialplot import radialplot
from pyRadialPlot import read_radialplotter_file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-86ae90906eab> in <module>
# ----> 1 from pyRadialPlot.radialplot import radialplot
#       2 from pyRadialPlot import read_radialplotter_file
#
# ModuleNotFoundError: No module named 'pyRadialPlot'

# %%
import matplotlib.pyplot as plt
fig = plt.Figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8], projection="radialplot")

# %%
data = read_radialplotter_file("FTdata.csv")

# %%
zeta = data["zeta"]
rhod = data["rhod"]
Ns = data["Ns"]
Ni = data["Ni"]

# %%
# %matplotlib tk
import matplotlib.pyplot as plt

fig = plt.Figure(figsize=(6,6))
ax = radialplot(Ns, Ni, zeta, rhod, transform="Logarithmic")

# %%
val = (ax.z - ax.z0) * 1e-6
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-742d5ecd05de> in <module>
# ----> 1 val = (ax.z - ax.z0) * 1e-6
#
# ~/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py in z(self)
#     157     def z(self):
#     158         """ Return transformed z-values"""
# --> 159         if self.transform == "Linear":
#     160             return  1.0 / LAMBDA * np.log(1.0 + G * self.zeta * LAMBDA * self.rhod * (self.Ns / self.Ni))
#     161
#
# AttributeError: 'Radialplot' object has no attribute 'transform'

# %%
import numpy as np

np.rad2deg(np.arctan(val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d534b4c02cb5> in <module>
#       1 import numpy as np
#       2
# ----> 3 np.rad2deg(np.arctan(val))
#
# NameError: name 'val' is not defined

# %%
val_x = 60
val_y = 396
central = 252

x = 1.0 / val_x
y = (val_y - central) / val_x

# %%
1.0 / 1.66e-8
# Out:
# 60240963.855421685

# %%
x
# Out:
# 0.016666666666666666

# %%
np.rad2deg(np.arctan(y / x))
# Out:
# 89.60211903816541

# %%
from pyFTracks.ressources import Miller1995

# %%
Ns = Miller1995["Ns (Number of spontaneous tracks)"]
Ni = Miller1995["Ni (Number of induced tracks)"]

zeta = 350.
zeta_err = 10. / 350.

rhod = 1304000
rhod_err = 0
Nd = 2936

# %%
Ns = list(Ns)
Ni = list(Ni)

# %%
rhod
# Out:
# 1304000

# %%
from pyRadialPlot import radialplot

ax = radialplot(Ns, Ni, zeta, rhod)

# %%
from pyFTracks.ressources import Gleadow

# %%
Ns = Gleadow["Ns (Number of spontaneous tracks)"]
Ni = Gleadow["Ni (Number of induced tracks)"]
zeta = 380.
zeta_err = 5. / 380.

rhod = 1.257
rhod_err = 0
Nd = 8188

# %%
Ns
# Out:
# 0       0
# 1       2
# 2      18
# 3       2
# 4      10
# 5       3
# 6       4
# 7      20
# 8      52
# 9       2
# 10      1
# 11      6
# 12    256
# 13     52
# 14      3
# 15     10
# 16      2
# 17      7
# 18      1
# 19     14
# 20     15
# 21     14
# 22      8
# 23     22
# 24     16
# 25     34
# 26     14
# 27      6
# 28     13
# 29    127
# Name: Ns (Number of spontaneous tracks), dtype: int64

# %%
from pyRadialPlot import radialplot


ax = radialplot(Ns, Ni, zeta, rhod)
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f4da8c61f80> (for post_execute):
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:147: RuntimeWarning: divide by zero encountered in log
#   return np.log(np.exp(LAMBDA * t) - 1)
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:179: RuntimeWarning: invalid value encountered in cos
#   x1 = R1 * np.cos(zr)
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:180: RuntimeWarning: invalid value encountered in sin
#   y1 = R1 * np.sin(zr)
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:181: RuntimeWarning: invalid value encountered in cos
#   x2 = R2 * np.cos(zr)
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:182: RuntimeWarning: invalid value encountered in sin
#   y2 = R2 * np.sin(zr)
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:228: RuntimeWarning: invalid value encountered in cos
#   x1 = R3 * np.cos(labels)
# /home/romain/Dropbox/Projects/pyRadialPlot/pyRadialPlot/radialplot.py:229: RuntimeWarning: invalid value encountered in sin
#   y1 = R3 * np.sin(labels)
# /usr/lib/python3.7/site-packages/matplotlib/patches.py:1700: RuntimeWarning: invalid value encountered in cos
#   x = np.cos(theta)
# /usr/lib/python3.7/site-packages/matplotlib/patches.py:1701: RuntimeWarning: invalid value encountered in sin
#   y = np.sin(theta)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# /usr/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# /usr/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /usr/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /usr/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/patches.py in draw(self, renderer)
#    1708         inv_error = (1.0 / 1.89818e-6) * 0.5
#    1709         if width < inv_error and height < inv_error:
# -> 1710             self._path = Path.arc(theta1, theta2)
#    1711             return Patch.draw(self, renderer)
#    1712
#
# /usr/lib/python3.7/site-packages/matplotlib/path.py in arc(cls, theta1, theta2, n, is_wedge)
#     836         # number of curve segments to make
#     837         if n is None:
# --> 838             n = int(2 ** np.ceil((eta2 - eta1) / halfpi))
#     839         if n < 1:
#     840             raise ValueError("n must be >= 1 or None")
#
# ValueError: cannot convert float NaN to integer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /usr/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /usr/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /usr/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /usr/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3.7/site-packages/matplotlib/patches.py in draw(self, renderer)
#    1708         inv_error = (1.0 / 1.89818e-6) * 0.5
#    1709         if width < inv_error and height < inv_error:
# -> 1710             self._path = Path.arc(theta1, theta2)
#    1711             return Patch.draw(self, renderer)
#    1712
#
# /usr/lib/python3.7/site-packages/matplotlib/path.py in arc(cls, theta1, theta2, n, is_wedge)
#     836         # number of curve segments to make
#     837         if n is None:
# --> 838             n = int(2 ** np.ceil((eta2 - eta1) / halfpi))
#     839         if n < 1:
#     840             raise ValueError("n must be >= 1 or None")
#
# ValueError: cannot convert float NaN to integer

# %%
import numpy as np

# %%
np.log(0)

# %%
from matplotlib.ticker import LinearLocator

vmin = 0.
vmax = 10.


l = LinearLocator(5)
l.tick_values(vmin, vmax)
ax.xaxis.set_major_locator(loc)

# %%
A = [1, 2, 3, 0]
B = [0, 2, 3, 1]

# %%
import numpy as np

# %%
D = np.ndarray((len(A), 2), dtype=int)

# %%
D[:, 0] = A
D[:, 1] = B

# %%
D

# %%
D[(D[:, 0] != 0) & (D[:, 1] != 0) , :]
