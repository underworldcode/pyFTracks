# %% [markdown]
# # Thermal History subdivision for calculation in isothermal intervals
#
# The more segments a time-temperature path is subdivided into, the more accurate
# the numerical solution will be. Conversely, an excessive number of time steps
# will slow computation down unnecessarily. The optimal time step size to achieve a desired
# solution accuracy was examined in detail by Issler (1996b), who demonstrated that time
# steps should be smaller as the total annealing temperature of apatite is approached.
# For the Ketcham et al. (1999) annealing model for F-apatite, Ketcham et al. (2000) found that 0.5% precision is assured if there is no step with greater than a 3.5 ºC change within 10 ºC of the F-apatite total annealing temperature.
#
# The thermal histories are calibrated to facilitate 0.5% accuracy for end-member F-apatite by having a maximum temperature step of 3.5 degrees C when the model temperature is within 10C of the total annealing temperature. Before this cutoff the maximum temperature step required is 8C. If the overall model tine steps are too large, these more distant requirement may not be meet.

# %%
from pyFTracks.thermal_history import *

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 5))
plt.plot(WOLF1.input_time, WOLF1.input_temperature, label="Wolf1", marker="o")
plt.plot(WOLF2.input_time, WOLF2.input_temperature, label="Wolf2", marker="o")
plt.plot(WOLF3.input_time, WOLF3.input_temperature, label="Wolf3", marker="o")
plt.plot(WOLF4.input_time, WOLF4.input_temperature, label="Wolf4", marker="o")
plt.plot(WOLF5.input_time, WOLF5.input_temperature, label="Wolf5", marker="o")
plt.xlim(100., 0.)
plt.ylim(150. + 273.15, 0.+273.15)
plt.ylabel("Temperature in degC")
plt.xlabel("Time in (Ma)")
plt.legend()

# %% [markdown]
# # Refine Thermal Histories in isothermal intervals

# %%
plt.figure(figsize=(15, 5))
plt.plot(WOLF1.time, WOLF1.temperature, label="Wolf1", marker="o")
plt.plot(WOLF2.time, WOLF2.temperature, label="Wolf2", marker="o")
plt.plot(WOLF3.time, WOLF3.temperature, label="Wolf3", marker="o")
plt.plot(WOLF4.time, WOLF4.temperature, label="Wolf4", marker="o")
plt.plot(WOLF5.time, WOLF5.temperature, label="Wolf5", marker="o")
plt.xlim(100., 0.)
plt.ylim(150. + 273.15, 0. + 273.15)
plt.ylabel("Temperature in degC")
plt.xlabel("Time in (Ma)")
plt.legend()

# %% [markdown]
# ## References
#
# Ketcham, R. A. (2005). Forward and Inverse Modeling of Low-Temperature
# Thermochronometry Data. Reviews in Mineralogy and Geochemistry, 58(1),
# 275–314. doi:10.2138/rmg.2005.58.11
