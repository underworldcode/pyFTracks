# %% [markdown]
# # The External Detector Method

# %% [markdown]
# # A typical dataset
#
# We provide an example of fission-track counts obtained by Miller et al, 1995 using the external detector method.

# %%
from pyFTracks.ressources import Miller1995

# %%
Miller1995
# Out:
#     Ns  Ni   A     Ns/Ni          RhoS          RhoI        Ages  Ages Errors
# 0   31  41  40  0.756098  8.602509e+05  1.137751e+06  170.272777    40.938206
# 1   19  22  20  0.863636  1.054501e+06  1.221001e+06  194.129222    61.156267
# 2   56  63  60  0.888889  1.036001e+06  1.165501e+06  199.718474    37.303586
# 3   67  71  80  0.943662  9.296259e+05  9.851260e+05  211.825011    36.791026
# 4   88  90  90  0.977778  1.085334e+06  1.110001e+06  219.354179    33.720434
# 5    6   7  15  0.857143  4.440004e+05  5.180005e+05  192.691202   107.403652
# 6   18  14  20  1.285714  9.990010e+05  7.770008e+05  286.919063   102.707829
# 7   40  41  40  0.975610  1.110001e+06  1.137751e+06  218.875970    49.209223
# 8   36  49  40  0.734694  9.990010e+05  1.359751e+06  165.514024    36.766051
# 9   54  79  60  0.683544  9.990010e+05  1.461501e+06  154.127518    27.714542
# 10  35  52  40  0.673077  9.712510e+05  1.443001e+06  151.794873    33.587209
# 11  52  76  70  0.684211  8.245723e+05  1.205144e+06  154.275956    28.256344
# 12  51  74  49  0.689189  1.155307e+06  1.676328e+06  155.385125    28.768616
# 13  47  66  50  0.712121  1.043401e+06  1.465201e+06  160.491558    31.114275
# 14  27  39  36  0.692308  8.325008e+05  1.202501e+06  156.079781    39.434473
# 15  36  44  40  0.818182  9.990010e+05  1.221001e+06  184.056340    41.834664
# 16  64  86  50  0.744186  1.420801e+06  1.909202e+06  167.624884    28.253537
# 17  68  90  50  0.755556  1.509602e+06  1.998002e+06  170.152315    27.945372
# 18  61  91  60  0.670330  1.128501e+06  1.683502e+06  151.182510    25.540172
# 19  30  41  30  0.731707  1.110001e+06  1.517002e+06  164.849733    40.001291

# %% [markdown]
# The table presents counts and counting areas from 20 apatite grain separated from a rock sample with an age of 162Ma independently determined using the $^{40}\text{Ar}^{39}\text{Ar}$ method.

# %%
data = Miller1995.iloc[:, :4]
data.columns = ["Grain", "Ns", "Ni", "A"]

# %%
data
# Out:
#     Grain  Ns  Ni         A
# 0      31  41  40  0.756098
# 1      19  22  20  0.863636
# 2      56  63  60  0.888889
# 3      67  71  80  0.943662
# 4      88  90  90  0.977778
# 5       6   7  15  0.857143
# 6      18  14  20  1.285714
# 7      40  41  40  0.975610
# 8      36  49  40  0.734694
# 9      54  79  60  0.683544
# 10     35  52  40  0.673077
# 11     52  76  70  0.684211
# 12     51  74  49  0.689189
# 13     47  66  50  0.712121
# 14     27  39  36  0.692308
# 15     36  44  40  0.818182
# 16     64  86  50  0.744186
# 17     68  90  50  0.755556
# 18     61  91  60  0.670330
# 19     30  41  30  0.731707

# %% [markdown]
# ## Fission Track Age (Zeta ($\zeta$) method)
#
# The fission-track age equation expressed using the analyst $\zeta$ value as the form:
#
# $$t = \frac{1}{\lambda} \log \left( 1 + \frac{1}{2} \lambda \zeta \rho_d \frac{\rho_s}{\rho_i} \right)$$
#
# Where $\zeta$ is a constant determined empirically using standards of known ages and is specific to the person counting the tracks.
#
# The track densities $\rho_s$ and $\rho_i$ can be estimated using the number of tracks counted $N_s$ and $N_i$ over an area $A$.
#
# $$\hat{\rho_s} = \frac{N_s}{A} \space\text{and}\space \hat{\rho_i} = \frac{N_i}{A}$$
#
# Subsituting gives the following equation:
#
# $$t = \frac{1}{\lambda} \log \left( 1 + \frac{1}{2} \lambda \zeta \rho_d \frac{N_s}{N_i} \right)$$

# %%
import numpy as np
rho_d = 1.304
zeta = 350.
lbd = 1.55125e-4
data["age"] = 1.0 / lbd * np.log(1.0 + 0.5 * lbd * zeta * rho_d * data["Ns"] / data["Ni"] )

# %%
data
# Out:
#     Grain  Ns  Ni         A         age
# 0      31  41  40  0.756098  229.761371
# 1      19  22  20  0.863636  246.255985
# 2      56  63  60  0.888889  235.264267
# 3      67  71  80  0.943662  199.411191
# 4      88  90  90  0.977778  224.253774
# 5       6   7  15  0.857143  105.623279
# 6      18  14  20  1.285714  157.792947
# 7      40  41  40  0.975610  229.761371
# 8      36  49  40  0.734694  273.653564
# 9      54  79  60  0.683544  293.671375
# 10     35  52  40  0.673077  290.036394
# 11     52  76  70  0.684211  243.117406
# 12     51  74  49  0.689189  335.732256
# 13     47  66  50  0.712121  294.398126
# 14     27  39  36  0.692308  242.594161
# 15     36  44  40  0.818182  246.255985
# 16     64  86  50  0.744186  381.018683
# 17     68  90  50  0.755556  398.203994
# 18     61  91  60  0.670330  337.132026
# 19     30  41  30  0.731707  304.564038

# %% [markdown]
# The approximate relative standard error is given by
#
# $$\frac{se(t)}{t}\approx \left( \frac{1}{N_s} + \frac{1}{N_i} + \frac{1}{N_d} + \left(\frac{se(\zeta)}{\zeta}\right)^2 \right)^{\frac{1}{2}}$$

# %%
Nd = 2936
zeta_err = 10. / 350.
data["rse"] = (1 / data["Ns"] + 1 / data["Ni"] + 1 / Nd + zeta_err**2)**0.5
data["se"] = data["rse"] * data["age"]

# %%
data
# Out:
#     Grain  Ns  Ni         A         age       rse         se
# 0      31  41  40  0.756098  229.761371  0.224827  51.656555
# 1      19  22  20  0.863636  246.255985  0.310824  76.542236
# 2      56  63  60  0.888889  235.264267  0.183566  43.186605
# 3      67  71  80  0.943662  199.411191  0.166558  33.213449
# 4      88  90  90  0.977778  224.253774  0.152902  34.288943
# 5       6   7  15  0.857143  105.623279  0.459000  48.481055
# 6      18  14  20  1.285714  157.792947  0.350122  55.246801
# 7      40  41  40  0.975610  229.761371  0.224827  51.656555
# 8      36  49  40  0.734694  273.653564  0.215789  59.051554
# 9      54  79  60  0.683544  293.671375  0.174590  51.272214
# 10     35  52  40  0.673077  290.036394  0.213044  61.790479
# 11     52  76  70  0.684211  243.117406  0.169117  41.115269
# 12     51  74  49  0.689189  335.732256  0.187293  62.880243
# 13     47  66  50  0.712121  294.398126  0.190548  56.096897
# 14     27  39  36  0.692308  242.594161  0.233614  56.673511
# 15     36  44  40  0.818182  246.255985  0.221098  54.446635
# 16     64  86  50  0.744186  381.018683  0.181066  68.989462
# 17     68  90  50  0.755556  398.203994  0.179633  71.530603
# 18     61  91  60  0.670330  337.132026  0.169743  57.225720
# 19     30  41  30  0.731707  304.564038  0.242653  73.903393

# %%
data["Ns/Ni"] = data["Ns"] / data["Ni"]
data["rhos"] = data["Ns"] / (data["A"] * 0.9009)
data["rhoi"] = data["Ni"] / (data["A"] * 0.9009)

# %%
data
# Out:
#     Grain  Ns  Ni         A         age       rse         se     Ns/Ni  \
# 0      31  41  40  0.756098  229.761371  0.224827  51.656555  1.025000
# 1      19  22  20  0.863636  246.255985  0.310824  76.542236  1.100000
# 2      56  63  60  0.888889  235.264267  0.183566  43.186605  1.050000
# 3      67  71  80  0.943662  199.411191  0.166558  33.213449  0.887500
# 4      88  90  90  0.977778  224.253774  0.152902  34.288943  1.000000
# 5       6   7  15  0.857143  105.623279  0.459000  48.481055  0.466667
# 6      18  14  20  1.285714  157.792947  0.350122  55.246801  0.700000
# 7      40  41  40  0.975610  229.761371  0.224827  51.656555  1.025000
# 8      36  49  40  0.734694  273.653564  0.215789  59.051554  1.225000
# 9      54  79  60  0.683544  293.671375  0.174590  51.272214  1.316667
# 10     35  52  40  0.673077  290.036394  0.213044  61.790479  1.300000
# 11     52  76  70  0.684211  243.117406  0.169117  41.115269  1.085714
# 12     51  74  49  0.689189  335.732256  0.187293  62.880243  1.510204
# 13     47  66  50  0.712121  294.398126  0.190548  56.096897  1.320000
# 14     27  39  36  0.692308  242.594161  0.233614  56.673511  1.083333
# 15     36  44  40  0.818182  246.255985  0.221098  54.446635  1.100000
# 16     64  86  50  0.744186  381.018683  0.181066  68.989462  1.720000
# 17     68  90  50  0.755556  398.203994  0.179633  71.530603  1.800000
# 18     61  91  60  0.670330  337.132026  0.169743  57.225720  1.516667
# 19     30  41  30  0.731707  304.564038  0.242653  73.903393  1.366667
#
#           rhos        rhoi
# 0    60.190705   58.722639
# 1    28.275818   25.705289
# 2    78.671329   74.925075
# 3    83.515158   94.101587
# 4   102.170557  102.170557
# 5     9.065009   19.425019
# 6    12.086679   17.266684
# 7    46.647797   45.510046
# 8    74.030907   60.433394
# 9   128.287351   97.433431
# 10   85.755514   65.965780
# 11  123.295508  113.561652
# 12  119.183649   78.918902
# 13  102.875848   77.936248
# 14   62.530063   57.720058
# 15   59.693393   54.266721
# 16  128.274503   74.578200
# 17  132.220720   73.455956
# 18  150.687200   99.354198
# 19   62.197062   45.510046

# %% [markdown]
# # Pooled Age

# %%
import numpy as np
rho_d = 1.304
zeta = 350.
lbd = 1.55125e-4
pooled_age = 1.0 / lbd * np.log(1.0 + 0.5 * lbd * zeta * rho_d * sum(data["Ns"]) / sum(data["Ni"]))
pooled_age_rse = (1 / sum(data["Ns"]) + 1 / sum(data["Ni"]) + 1 / Nd + zeta_err**2)**0.5
pooled_age_se = pooled_age_rse * pooled_age

# %%
pooled_age, pooled_age_se, pooled_age_rse
# Out:
# (270.04607568694706, 15.038044891244366, 0.055686959541961026)
