# %%
# %matplotlib inline
import pyFTracks
import numpy as np

# %% [markdown]
# Just create some dummy values for now

# %%
central = 100.
values = np.random.normal(central,30, size=100)
errors = np.random.normal(10,1, size=100)

radialplot = pyFTracks.Radialplot(values, errors, central)
radialplot.plot()
