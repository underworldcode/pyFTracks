# %% [markdown]
# # WOLF Histories Forward Models

# %%
from pyFTracks import Viewer
import pyFTracks.thermal_history as TH

# %%
Viewer(TH.WOLF1)

# %%
from pyFTracks.annealing import AnnealingModel

# %%
Viewer(TH.WOLF2)

# %%
Viewer(TH.WOLF3)

# %%
Viewer(TH.WOLF4)

# %%
Viewer(TH.WOLF5)

# %%
TH.WOLF1.input_temperature
# Out:
# [283.15, 283.15, 403.15, 403.15]
