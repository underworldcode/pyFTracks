# %% [markdown]
# # WOLF Histories Forward Models

# %%
#%matplotlib tk
import pyFTracks as FT
from pyFTracks import Viewer
import pyFTracks.thermal_history as TH

# %%
model = FT.Ketcham1999(kinetic_parameters={"ETCH_PIT_LENGTH": 1.65})

model.history = TH.WOLF1
model.calculate_age()

synthetic_wolf1 = model.generate_synthetic_sample()

# %%
Viewer(TH.WOLF1, annealing_model=model, sample=synthetic_wolf1)

# %%
model = FT.Ketcham1999(kinetic_parameters={"ETCH_PIT_LENGTH": 1.65})

model.history = TH.WOLF2
model.calculate_age()

synthetic_wolf2 = model.generate_synthetic_sample()

# %%
Viewer(TH.WOLF2, annealing_model=model, sample=synthetic_wolf2)

# %%
model = FT.Ketcham1999(kinetic_parameters={"ETCH_PIT_LENGTH": 1.65})

model.history = TH.WOLF3
model.calculate_age()

synthetic_wolf3 = model.generate_synthetic_sample()

# %%
Viewer(TH.WOLF3, annealing_model=model, sample=synthetic_wolf3)

# %%
model = FT.Ketcham1999(kinetic_parameters={"ETCH_PIT_LENGTH": 1.65})

model.history = TH.WOLF4
model.calculate_age()

synthetic_wolf4 = model.generate_synthetic_sample()

# %%
Viewer(TH.WOLF4, annealing_model=model, sample=synthetic_wolf4)

# %%
model = FT.Ketcham1999(kinetic_parameters={"ETCH_PIT_LENGTH": 1.65})

model.history = TH.WOLF5
model.calculate_age()

synthetic_wolf5 = model.generate_synthetic_sample()

# %%
Viewer(TH.WOLF5, annealing_model=model, sample=synthetic_wolf5)
